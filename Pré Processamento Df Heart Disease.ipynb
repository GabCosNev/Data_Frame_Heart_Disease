# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv('new_heart.csv', sep=',', encoding='utf-8')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140        289.0          0     Normal    172
# 1   49   F           NAP        160        180.0          0     Normal    156
# 2   37   M           ATA        130        283.0          0         ST     98
# 3   48   F           ASY        138        214.0          0     Normal    108
# 4   54   M           NAP        150        195.0          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#Transformando Valores Nominais em Ordinais

df_alterado = df.iloc[:, 0:12].values
lista = [1,2,6,8,10]
for i in lista:
    df_alterado[:,i] = LabelEncoder().fit_transform(df_alterado[:,i])

#Transformando em DataFrame novamente

colunas = df.columns[0:12]

df_alterado = pd.DataFrame(data=df_alterado, columns=colunas)

for i in range(12):
    df_alterado[df_alterado.columns[i]] = df_alterado[df_alterado.columns[i]].astype(int)

df_alterado
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 912   45    1              3        110          264          0           1
# 913   68    1              0        144          193          1           1
# 914   57    1              0        130          131          0           1
# 915   57    0              1        130          236          0           0
# 916   38    1              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0      172               0        0         2             0
# 1      156               0        1         1             1
# 2       98               0        0         2             0
# 3      108               1        1         1             1
# 4      122               0        0         2             0
# ..     ...             ...      ...       ...           ...
# 912    132               0        1         1             1
# 913    141               0        3         1             1
# 914    115               1        1         1             1
# 915    174               0        0         1             1
# 916    173               0        0         2             0
#
# [917 rows x 12 columns]

# %%
previsores = df_alterado.iloc[:, 0:11].values
previsores
# Out:
# array([[40,  1,  1, ...,  0,  0,  2],
#        [49,  0,  2, ...,  0,  1,  1],
#        [37,  1,  1, ...,  0,  0,  2],
#        ...,
#        [57,  1,  0, ...,  1,  1,  1],
#        [57,  0,  1, ...,  0,  0,  1],
#        [38,  1,  2, ...,  0,  0,  2]])

# %%
# Armazenando coluna HeartDisease para testes
alvo = df_alterado.iloc[:, 11].values

# %%
df_alterado.describe()
# Out:
#               Age         Sex  ChestPainType   RestingBP  Cholesterol  \
# count  917.000000  917.000000     917.000000  917.000000   917.000000
# mean    53.509269    0.789531       0.779716  132.540894   244.516903
# std      9.437636    0.407864       0.956193   17.999749    53.347700
# min     28.000000    0.000000       0.000000   80.000000    85.000000
# 25%     47.000000    1.000000       0.000000  120.000000   214.000000
# 50%     54.000000    1.000000       0.000000  130.000000   244.000000
# 75%     60.000000    1.000000       2.000000  140.000000   267.000000
# max     77.000000    1.000000       3.000000  200.000000   603.000000
#
#         FastingBS  RestingECG       MaxHR  ExerciseAngina     Oldpeak  \
# count  917.000000  917.000000  917.000000      917.000000  917.000000
# mean     0.233370    0.989095  136.789531        0.404580    0.719738
# std      0.423206    0.632016   25.467129        0.491078    0.990662
# min      0.000000    0.000000   60.000000        0.000000   -2.000000
# 25%      0.000000    1.000000  120.000000        0.000000    0.000000
# 50%      0.000000    1.000000  138.000000        0.000000    0.000000
# 75%      0.000000    1.000000  156.000000        1.000000    1.000000
# max      1.000000    2.000000  202.000000        1.000000    6.000000
#
#         ST_Slope  HeartDisease
# count  917.00000    917.000000
# mean     1.36205      0.552890
# std      0.60727      0.497466
# min      0.00000      0.000000
# 25%      1.00000      0.000000
# 50%      1.00000      1.000000
# 75%      2.00000      1.000000
# max      2.00000      1.000000

# %%
previsores_esc = StandardScaler().fit_transform(previsores)
previsores_esc
# Out:
# array([[-1.43220634,  0.51630861,  0.23050141, ..., -0.82431012,
#         -0.72691898,  1.05109458],
#        [-0.47805725, -1.9368261 ,  1.27688653, ..., -0.82431012,
#          0.28305784, -0.59651863],
#        [-1.75025603,  0.51630861,  0.23050141, ..., -0.82431012,
#         -0.72691898,  1.05109458],
#        ...,
#        [ 0.37007527,  0.51630861, -0.8158837 , ...,  1.21313565,
#          0.28305784, -0.59651863],
#        [ 0.37007527, -1.9368261 ,  0.23050141, ..., -0.82431012,
#         -0.72691898, -0.59651863],
#        [-1.64423947,  0.51630861,  1.27688653, ..., -0.82431012,
#         -0.72691898,  1.05109458]])

# %%
previsoresdf = pd.DataFrame(previsores_esc)
previsoresdf
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1